# %% [markdown]
# # Problem Setup
#   - How long would it take for a skillet to get hot over a small flame?
#   - Let's assume we can't look up the answer
#   - What would people do?

# %% [markdown]
# ## Place for notes

# %% [markdown]
# # Heat Equation
#
# $\frac{du}{dt} = \alpha \frac{d^2u}{dx^2}$
#
# $u_t = \alpha u_{xx}$
#
# $u_t = \alpha (u_{xx} + u_{yy})$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Okay let's start coding :)
